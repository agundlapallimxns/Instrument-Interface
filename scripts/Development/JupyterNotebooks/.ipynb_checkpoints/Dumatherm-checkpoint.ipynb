# %%
# Import Functions
import pandas as pd
import os
import time
import csv
import json
import fnmatch
import csv
import sqlalchemy as sql
import numpy as np
dbHost='mxnunx41'
dbPort='1521'
dbUser='lims'
dbPassword='Mumwit63'
dbName='hwi1'
dburl='oracle://'

# %%
# Default Parameters setting
with open('.\configFiles\DumathermConfig.json', 'r') as f:
    config = json.load(f)
lab = config['lab']
analysis = config['analysis']
inst = config['inst']
colsOrder=['Sample.Sample_Number', 'Test.Test_Number','Result.Name', 'Result.Entry', 'Result.Entered_By','Result.Instrument']

# %%
# get Data from DB
def getDataFromDB(sampleNumbersList):
    dburl = 'oracle://'+dbUser+':'+dbPassword+'@'+dbHost+':'+dbPort+'/'+dbName
    engine=sql.create_engine(dburl)
    resultdf=pd.DataFrame()
    sampleNumbrStr=(', '.join("'" + str(item) + "'" for item in sampleNumbersList))
    queryText="SELECT sample_number, analysis, REPLICATE_COUNT,TEST_NUMBER FROM test"
    queryText=queryText+" WHERE SAMPLE_NUMBER IN ("+sampleNumbrStr+") AND analysis IN ('PROT-COMII', 'PROT-HICOM')"
    conn = engine.connect()
    resultdf = pd.read_sql(queryText, engine)
    conn.close()
    return resultdf

# %%
#write the file
def writeFile(dframe,lab,inst,archDestination,importDest,datapath,fname):
    timestr = time.strftime("%Y%m%d%H%M%S")
    FileName = importDest + lab+'_'+inst+'_' + timestr + '.csv'
    dframe.to_csv(FileName, index=False, encoding="utf-8",quotechar='"',quoting=csv.QUOTE_NONNUMERIC) # write  out the file to be imported
    destination = archDestination + fname[:-4] + '.bak' # Backup the processed file
    os.rename(datapath, destination)
    time.sleep(1)

# %%
for eachlab in lab:
    path='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//Import//'+inst+'//'
    archivedDestination='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//Import//'+inst+'//'
    importDest='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//impf//'
    print(path)
    if os.path.exists(path):
        break
    else:
        os.makedirs(path)
    files = os.listdir(path)
    for filename in files:
        if fnmatch.fnmatch(filename,'*.CSV'):
            print (filename)
# Out:
# //mxns.loc//shares//NA-Instruments//Prod//Crete//Import//Dumatherm//

# %%
filename='Export_812_2019_03_18_09_25.csv'
datapath = path + str(filename)
rawdf = pd.read_csv(datapath,header=None)

# %%
rawdf = rawdf.rename(index=str, columns={0: 'sample_number', 1: 'var1', 2: 'var2'})

# %%
sampleNumbersList=list(rawdf['sample_number'].unique())
databasedf=getDataFromDB(sampleNumbersList)
rawdf=rawdf.astype({"sample_number": int})
dfResult = rawdf.merge(databasedf, how = 'inner', on = ['sample_number'])

# %%
dfResult
# Out:
#     sample_number   var1  var2    analysis  replicate_count  test_number
# 0       386356569  104.8  9.61  PROT-COMII                1    644031964
# 1       386356574  103.6  9.59  PROT-COMII                1    644031965
# 2       386356575  257.1  3.21  PROT-COMII                1    644031966
# 3       386260010  216.4  2.17  PROT-COMII                1    643824693
# 4       386260016  156.6  2.09  PROT-COMII                1    643824694
# 5       386260021  181.0  2.30  PROT-COMII                1    643824695
# 6       386260026  169.0  2.40  PROT-COMII                1    643824696
# 7       386260323  195.7  2.31  PROT-COMII                1    643825789
# 8       386260324  205.7  2.33  PROT-COMII                1    643825790
# 9       386260327  183.2  2.10  PROT-COMII                1    643825791
# 10      386260329  181.5  2.34  PROT-COMII                1    643825792
# 11      386289541  192.4  0.66  PROT-COMII                1    643897382
# 12      386289569  190.4  0.11  PROT-COMII                1    643899058
# 13      386289601  210.2  0.62  PROT-COMII                1    643899176
# 14      386289716  171.2  1.63  PROT-COMII                1    643899191
# 15      386289809  196.0  0.66  PROT-COMII                1    643899206
# 16      386356605  102.0  9.57  PROT-COMII                1    644031967
# 17      386297131  174.3  5.79  PROT-COMII                1    643910529
# 18      386308941  133.4  2.06  PROT-COMII                1    643939927
# 19      386308941  133.4  2.06  PROT-COMII                2    644090975
# 20      386326558  268.0  2.37  PROT-COMII                1    643978534
# 21      386326714  174.8  0.21  PROT-COMII                1    643978550
# 22      386326814  194.2  0.05  PROT-COMII                1    643979648
# 23      386327018  200.7  0.31  PROT-COMII                1    643980101
# 24      386327030  231.1  0.11  PROT-COMII                1    643979664
# 25      386356614  253.5  3.22  PROT-COMII                1    644032288
# 26      386356625  102.3  9.53  PROT-COMII                1    644032289

# %%
dfResult=dfResult.rename(index=str, 
columns={'sample_number': 'Sample.Sample_Number', 'var2': 'Result.Entry','test_number':'Test.Test_Number'})

# %%
dfResult
# Out:
#     Sample.Sample_Number   var1  Result.Entry    analysis  replicate_count  \
# 0              386356569  104.8          9.61  PROT-COMII                1
# 1              386356574  103.6          9.59  PROT-COMII                1
# 2              386356575  257.1          3.21  PROT-COMII                1
# 3              386260010  216.4          2.17  PROT-COMII                1
# 4              386260016  156.6          2.09  PROT-COMII                1
# 5              386260021  181.0          2.30  PROT-COMII                1
# 6              386260026  169.0          2.40  PROT-COMII                1
# 7              386260323  195.7          2.31  PROT-COMII                1
# 8              386260324  205.7          2.33  PROT-COMII                1
# 9              386260327  183.2          2.10  PROT-COMII                1
# 10             386260329  181.5          2.34  PROT-COMII                1
# 11             386289541  192.4          0.66  PROT-COMII                1
# 12             386289569  190.4          0.11  PROT-COMII                1
# 13             386289601  210.2          0.62  PROT-COMII                1
# 14             386289716  171.2          1.63  PROT-COMII                1
# 15             386289809  196.0          0.66  PROT-COMII                1
# 16             386356605  102.0          9.57  PROT-COMII                1
# 17             386297131  174.3          5.79  PROT-COMII                1
# 18             386308941  133.4          2.06  PROT-COMII                1
# 19             386308941  133.4          2.06  PROT-COMII                2
# 20             386326558  268.0          2.37  PROT-COMII                1
# 21             386326714  174.8          0.21  PROT-COMII                1
# 22             386326814  194.2          0.05  PROT-COMII                1
# 23             386327018  200.7          0.31  PROT-COMII                1
# 24             386327030  231.1          0.11  PROT-COMII                1
# 25             386356614  253.5          3.22  PROT-COMII                1
# 26             386356625  102.3          9.53  PROT-COMII                1
#
#     Test.Test_Number
# 0          644031964
# 1          644031965
# 2          644031966
# 3          643824693
# 4          643824694
# 5          643824695
# 6          643824696
# 7          643825789
# 8          643825790
# 9          643825791
# 10         643825792
# 11         643897382
# 12         643899058
# 13         643899176
# 14         643899191
# 15         643899206
# 16         644031967
# 17         643910529
# 18         643939927
# 19         644090975
# 20         643978534
# 21         643978550
# 22         643979648
# 23         643980101
# 24         643979664
# 25         644032288
# 26         644032289

# %%
dfResultReplicateMax = dfResult.groupby('Sample.Sample_Number')['replicate_count'].max().reset_index()
dfResultFinal = dfResult.merge(dfResultReplicateMax, how = 'inner', on = ['Sample.Sample_Number','replicate_count'])

# %%
dfResultFinal
# Out:
#     Sample.Sample_Number   var1  Result.Entry    analysis  replicate_count  \
# 0              386356569  104.8          9.61  PROT-COMII                1
# 1              386356574  103.6          9.59  PROT-COMII                1
# 2              386356575  257.1          3.21  PROT-COMII                1
# 3              386260010  216.4          2.17  PROT-COMII                1
# 4              386260016  156.6          2.09  PROT-COMII                1
# 5              386260021  181.0          2.30  PROT-COMII                1
# 6              386260026  169.0          2.40  PROT-COMII                1
# 7              386260323  195.7          2.31  PROT-COMII                1
# 8              386260324  205.7          2.33  PROT-COMII                1
# 9              386260327  183.2          2.10  PROT-COMII                1
# 10             386260329  181.5          2.34  PROT-COMII                1
# 11             386289541  192.4          0.66  PROT-COMII                1
# 12             386289569  190.4          0.11  PROT-COMII                1
# 13             386289601  210.2          0.62  PROT-COMII                1
# 14             386289716  171.2          1.63  PROT-COMII                1
# 15             386289809  196.0          0.66  PROT-COMII                1
# 16             386356605  102.0          9.57  PROT-COMII                1
# 17             386297131  174.3          5.79  PROT-COMII                1
# 18             386308941  133.4          2.06  PROT-COMII                2
# 19             386326558  268.0          2.37  PROT-COMII                1
# 20             386326714  174.8          0.21  PROT-COMII                1
# 21             386326814  194.2          0.05  PROT-COMII                1
# 22             386327018  200.7          0.31  PROT-COMII                1
# 23             386327030  231.1          0.11  PROT-COMII                1
# 24             386356614  253.5          3.22  PROT-COMII                1
# 25             386356625  102.3          9.53  PROT-COMII                1
#
#     Test.Test_Number
# 0          644031964
# 1          644031965
# 2          644031966
# 3          643824693
# 4          643824694
# 5          643824695
# 6          643824696
# 7          643825789
# 8          643825790
# 9          643825791
# 10         643825792
# 11         643897382
# 12         643899058
# 13         643899176
# 14         643899191
# 15         643899206
# 16         644031967
# 17         643910529
# 18         644090975
# 19         643978534
# 20         643978550
# 21         643979648
# 22         643980101
# 23         643979664
# 24         644032288
# 25         644032289

# %%
dfResultFinal['Result.Name']='Nitrogen (from instrument)'
dfResultFinal['Result.Entered_By']='IMPORTER'
dfResultFinal['Result.Instrument']='Dumatherm'

# %%
dfResultFinal
# Out:
#     Sample.Sample_Number   var1  Result.Entry    analysis  replicate_count  \
# 0              386356569  104.8          9.61  PROT-COMII                1
# 1              386356574  103.6          9.59  PROT-COMII                1
# 2              386356575  257.1          3.21  PROT-COMII                1
# 3              386260010  216.4          2.17  PROT-COMII                1
# 4              386260016  156.6          2.09  PROT-COMII                1
# 5              386260021  181.0          2.30  PROT-COMII                1
# 6              386260026  169.0          2.40  PROT-COMII                1
# 7              386260323  195.7          2.31  PROT-COMII                1
# 8              386260324  205.7          2.33  PROT-COMII                1
# 9              386260327  183.2          2.10  PROT-COMII                1
# 10             386260329  181.5          2.34  PROT-COMII                1
# 11             386289541  192.4          0.66  PROT-COMII                1
# 12             386289569  190.4          0.11  PROT-COMII                1
# 13             386289601  210.2          0.62  PROT-COMII                1
# 14             386289716  171.2          1.63  PROT-COMII                1
# 15             386289809  196.0          0.66  PROT-COMII                1
# 16             386356605  102.0          9.57  PROT-COMII                1
# 17             386297131  174.3          5.79  PROT-COMII                1
# 18             386308941  133.4          2.06  PROT-COMII                2
# 19             386326558  268.0          2.37  PROT-COMII                1
# 20             386326714  174.8          0.21  PROT-COMII                1
# 21             386326814  194.2          0.05  PROT-COMII                1
# 22             386327018  200.7          0.31  PROT-COMII                1
# 23             386327030  231.1          0.11  PROT-COMII                1
# 24             386356614  253.5          3.22  PROT-COMII                1
# 25             386356625  102.3          9.53  PROT-COMII                1
#
#     Test.Test_Number                 Result.Name Result.Entered_By  \
# 0          644031964  Nitrogen (from instrument)          IMPORTER
# 1          644031965  Nitrogen (from instrument)          IMPORTER
# 2          644031966  Nitrogen (from instrument)          IMPORTER
# 3          643824693  Nitrogen (from instrument)          IMPORTER
# 4          643824694  Nitrogen (from instrument)          IMPORTER
# 5          643824695  Nitrogen (from instrument)          IMPORTER
# 6          643824696  Nitrogen (from instrument)          IMPORTER
# 7          643825789  Nitrogen (from instrument)          IMPORTER
# 8          643825790  Nitrogen (from instrument)          IMPORTER
# 9          643825791  Nitrogen (from instrument)          IMPORTER
# 10         643825792  Nitrogen (from instrument)          IMPORTER
# 11         643897382  Nitrogen (from instrument)          IMPORTER
# 12         643899058  Nitrogen (from instrument)          IMPORTER
# 13         643899176  Nitrogen (from instrument)          IMPORTER
# 14         643899191  Nitrogen (from instrument)          IMPORTER
# 15         643899206  Nitrogen (from instrument)          IMPORTER
# 16         644031967  Nitrogen (from instrument)          IMPORTER
# 17         643910529  Nitrogen (from instrument)          IMPORTER
# 18         644090975  Nitrogen (from instrument)          IMPORTER
# 19         643978534  Nitrogen (from instrument)          IMPORTER
# 20         643978550  Nitrogen (from instrument)          IMPORTER
# 21         643979648  Nitrogen (from instrument)          IMPORTER
# 22         643980101  Nitrogen (from instrument)          IMPORTER
# 23         643979664  Nitrogen (from instrument)          IMPORTER
# 24         644032288  Nitrogen (from instrument)          IMPORTER
# 25         644032289  Nitrogen (from instrument)          IMPORTER
#
#    Result.Instrument
# 0          Dumatherm
# 1          Dumatherm
# 2          Dumatherm
# 3          Dumatherm
# 4          Dumatherm
# 5          Dumatherm
# 6          Dumatherm
# 7          Dumatherm
# 8          Dumatherm
# 9          Dumatherm
# 10         Dumatherm
# 11         Dumatherm
# 12         Dumatherm
# 13         Dumatherm
# 14         Dumatherm
# 15         Dumatherm
# 16         Dumatherm
# 17         Dumatherm
# 18         Dumatherm
# 19         Dumatherm
# 20         Dumatherm
# 21         Dumatherm
# 22         Dumatherm
# 23         Dumatherm
# 24         Dumatherm
# 25         Dumatherm

# %%
dfResultFinal = dfResultFinal[colsOrder]

# %%
dfResultFinal
# Out:
#     Sample.Sample_Number  Test.Test_Number                 Result.Name  \
# 0              386356569         644031964  Nitrogen (from instrument)
# 1              386356574         644031965  Nitrogen (from instrument)
# 2              386356575         644031966  Nitrogen (from instrument)
# 3              386260010         643824693  Nitrogen (from instrument)
# 4              386260016         643824694  Nitrogen (from instrument)
# 5              386260021         643824695  Nitrogen (from instrument)
# 6              386260026         643824696  Nitrogen (from instrument)
# 7              386260323         643825789  Nitrogen (from instrument)
# 8              386260324         643825790  Nitrogen (from instrument)
# 9              386260327         643825791  Nitrogen (from instrument)
# 10             386260329         643825792  Nitrogen (from instrument)
# 11             386289541         643897382  Nitrogen (from instrument)
# 12             386289569         643899058  Nitrogen (from instrument)
# 13             386289601         643899176  Nitrogen (from instrument)
# 14             386289716         643899191  Nitrogen (from instrument)
# 15             386289809         643899206  Nitrogen (from instrument)
# 16             386356605         644031967  Nitrogen (from instrument)
# 17             386297131         643910529  Nitrogen (from instrument)
# 18             386308941         644090975  Nitrogen (from instrument)
# 19             386326558         643978534  Nitrogen (from instrument)
# 20             386326714         643978550  Nitrogen (from instrument)
# 21             386326814         643979648  Nitrogen (from instrument)
# 22             386327018         643980101  Nitrogen (from instrument)
# 23             386327030         643979664  Nitrogen (from instrument)
# 24             386356614         644032288  Nitrogen (from instrument)
# 25             386356625         644032289  Nitrogen (from instrument)
#
#     Result.Entry Result.Entered_By Result.Instrument
# 0           9.61          IMPORTER         Dumatherm
# 1           9.59          IMPORTER         Dumatherm
# 2           3.21          IMPORTER         Dumatherm
# 3           2.17          IMPORTER         Dumatherm
# 4           2.09          IMPORTER         Dumatherm
# 5           2.30          IMPORTER         Dumatherm
# 6           2.40          IMPORTER         Dumatherm
# 7           2.31          IMPORTER         Dumatherm
# 8           2.33          IMPORTER         Dumatherm
# 9           2.10          IMPORTER         Dumatherm
# 10          2.34          IMPORTER         Dumatherm
# 11          0.66          IMPORTER         Dumatherm
# 12          0.11          IMPORTER         Dumatherm
# 13          0.62          IMPORTER         Dumatherm
# 14          1.63          IMPORTER         Dumatherm
# 15          0.66          IMPORTER         Dumatherm
# 16          9.57          IMPORTER         Dumatherm
# 17          5.79          IMPORTER         Dumatherm
# 18          2.06          IMPORTER         Dumatherm
# 19          2.37          IMPORTER         Dumatherm
# 20          0.21          IMPORTER         Dumatherm
# 21          0.05          IMPORTER         Dumatherm
# 22          0.31          IMPORTER         Dumatherm
# 23          0.11          IMPORTER         Dumatherm
# 24          3.22          IMPORTER         Dumatherm
# 25          9.53          IMPORTER         Dumatherm

# %%
writeFile(dfResultFinal,eachlab,inst,path,importDest,datapath,filename)

# %%
# Import Functions
import pandas as pd
import os
import time
import csv
import json
import fnmatch
import csv
import sqlalchemy as sql
import numpy as np
dbHost='mxnunx41'
dbPort='1521'
dbUser='lims'
dbPassword='Mumwit63'
dbName='hwi1'
dburl='oracle://'

# %%
# Default Parameters setting
with open('.//configFiles//BioRad.json', 'r') as f:
    config = json.load(f)
lab = config['lab']
analysis = config['analysis']
inst = config['inst']
mode = config['mode']
colsOrder=['Sample.Sample_Number', 'Test.Test_Number','Result.Name', 'Result.Entry', 'Result.Entered_By','Result.Instrument']

# %%
# get Data from DB
def getDataFromDB(sampleNumbersList):
    dburl = 'oracle://'+dbUser+':'+dbPassword+'@'+dbHost+':'+dbPort+'/'+dbName
    engine=sql.create_engine(dburl)
    resultdf=pd.DataFrame()
    sampleNumbrStr=(', '.join("'" + item + "'" for item in sampleNumbersList))
    queryText="SELECT sample_number, analysis, REPLICATE_COUNT,TEST_NUMBER FROM test"
    queryText=queryText+" WHERE SAMPLE_NUMBER IN ("+sampleNumbrStr+") AND analysis IN ('LSP-IQ125C')"
    conn = engine.connect()
    resultdf = pd.read_sql(queryText, engine)
    conn.close()
    return resultdf

# %%
#write the file
def writeFile(dframe,lab,inst,archDestination,importDest,datapath,fname):
    timestr = time.strftime("%Y%m%d%H%M%S")
    FileName = importDest + lab+'_'+inst+'_' + timestr + '.csv'
    dframe.to_csv(FileName, index=False, encoding="utf-8",quotechar='"',quoting=csv.QUOTE_NONNUMERIC) # write  out the file to be imported
    destination = archDestination + fname[:-4] + '.bak' # Backup the processed file
    os.rename(datapath, destination)
    time.sleep(1)

# %%
for eachlab in lab:
    print('Lab:'+eachlab)
    path= './/SampleFiles_Instruments//BioRad//'
    '''
    path='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//Import//'+inst+'//'
    archivedDestination='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//Import//'+inst+'//'
    if(mode=='T'):
        importDest='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//impf//testing//'
    else:
        importDest='//mxns.loc//shares//NA-Instruments//Prod//'+eachlab+'//impf//'
    if os.path.exists(path):
        pass
    else:
        os.makedirs(path)
    if os.path.exists(importDest):
        pass
    else:
        os.makedirs(importDest)
    '''
    files = os.listdir(path)
    for filename in files:
        if fnmatch.fnmatch(filename,'*.CSV'):
            print (filename)
# Out:
# Lab:Burnanby
# admin_2019-06-04 16-24-19_CT016386_L. mono..csv
# admin_2019-06-04 19-36-22_CT016386_L. mono..csv
# admin_2019-06-04 22-08-06_CT016386_L. mono..csv

# %%
path= './/SampleFiles_Instruments//BioRad//'
filename='admin_2019-06-04 16-24-19_CT016386_L. mono..csv'
datapath = path + str(filename)
rawdf = pd.read_csv(datapath,sep=',',index_col=False,skiprows=23)

# %%
rawdf
# Out:
#     A02  FAM  Unnamed: 2      Unkn  Unnamed: 4    388787724  Unnamed: 6  \
# 0   A04  FAM         NaN  Neg Ctrl         NaN          NaN         NaN
# 1   B01  FAM         NaN      Unkn         NaN  388787661.0         NaN
# 2   B02  FAM         NaN      Unkn         NaN  388787731.0         NaN
# 3   B04  FAM         NaN  Pos Ctrl         NaN          NaN         NaN
# 4   C01  FAM         NaN      Unkn         NaN  388787677.0         NaN
# 5   C02  FAM         NaN      Unkn         NaN  388787738.0         NaN
# 6   D01  FAM         NaN      Unkn         NaN  388787681.0         NaN
# 7   D02  FAM         NaN      Unkn         NaN  388769819.0         NaN
# 8   E01  FAM         NaN      Unkn         NaN  388787685.0         NaN
# 9   E02  FAM         NaN      Unkn         NaN  388769824.0         NaN
# 10  F01  FAM         NaN      Unkn         NaN  388787711.0         NaN
# 11  G01  FAM         NaN      Unkn         NaN  388787715.0         NaN
# 12  H01  FAM         NaN      Unkn         NaN  388787719.0         NaN
# 13  A01  HEX         NaN      Unkn         NaN  388787656.0         NaN
# 14  A02  HEX         NaN      Unkn         NaN  388787724.0         NaN
# 15  A04  HEX         NaN  Neg Ctrl         NaN          NaN         NaN
# 16  B01  HEX         NaN      Unkn         NaN  388787661.0         NaN
# 17  B02  HEX         NaN      Unkn         NaN  388787731.0         NaN
# 18  B04  HEX         NaN  Pos Ctrl         NaN          NaN         NaN
# 19  C01  HEX         NaN      Unkn         NaN  388787677.0         NaN
# 20  C02  HEX         NaN      Unkn         NaN  388787738.0         NaN
# 21  D01  HEX         NaN      Unkn         NaN  388787681.0         NaN
# 22  D02  HEX         NaN      Unkn         NaN  388769819.0         NaN
# 23  E01  HEX         NaN      Unkn         NaN  388787685.0         NaN
# 24  E02  HEX         NaN      Unkn         NaN  388769824.0         NaN
# 25  F01  HEX         NaN      Unkn         NaN  388787711.0         NaN
# 26  G01  HEX         NaN      Unkn         NaN  388787715.0         NaN
# 27  H01  HEX         NaN      Unkn         NaN  388787719.0         NaN
#
#     Unnamed: 7        NaN  NaN.1          0  0.1  0.2  Unnamed: 13  \
# 0          NaN        NaN    NaN   0.000000    0    0          NaN
# 1          NaN        NaN    NaN   0.000000    0    0          NaN
# 2          NaN        NaN    NaN   0.000000    0    0          NaN
# 3          NaN  30.487145    NaN  30.487145    0    0          NaN
# 4          NaN        NaN    NaN   0.000000    0    0          NaN
# 5          NaN        NaN    NaN   0.000000    0    0          NaN
# 6          NaN        NaN    NaN   0.000000    0    0          NaN
# 7          NaN        NaN    NaN   0.000000    0    0          NaN
# 8          NaN        NaN    NaN   0.000000    0    0          NaN
# 9          NaN  24.171032    NaN  24.171032    0    0          NaN
# 10         NaN        NaN    NaN   0.000000    0    0          NaN
# 11         NaN        NaN    NaN   0.000000    0    0          NaN
# 12         NaN        NaN    NaN   0.000000    0    0          NaN
# 13         NaN  35.290490    NaN  35.290490    0    0          NaN
# 14         NaN  33.328239    NaN  33.328239    0    0          NaN
# 15         NaN  33.807567    NaN  33.807567    0    0          NaN
# 16         NaN  35.641533    NaN  35.641533    0    0          NaN
# 17         NaN  33.682748    NaN  33.682748    0    0          NaN
# 18         NaN  33.271358    NaN  33.271358    0    0          NaN
# 19         NaN  35.224962    NaN  35.224962    0    0          NaN
# 20         NaN  34.369400    NaN  34.369400    0    0          NaN
# 21         NaN  34.787182    NaN  34.787182    0    0          NaN
# 22         NaN  33.381608    NaN  33.381608    0    0          NaN
# 23         NaN  35.751486    NaN  35.751486    0    0          NaN
# 24         NaN  32.611949    NaN  32.611949    0    0          NaN
# 25         NaN  34.759082    NaN  34.759082    0    0          NaN
# 26         NaN  34.387647    NaN  34.387647    0    0          NaN
# 27         NaN  33.357476    NaN  33.357476    0    0          NaN
#
#     Unnamed: 14  Unnamed: 15  Unnamed: 16   Unnamed: 17  -227.436497324491  \
# 0           NaN          NaN          NaN           NaN          26.253294
# 1           NaN          NaN          NaN           NaN        -189.940272
# 2           NaN          NaN          NaN           NaN        -603.584588
# 3           NaN          NaN          NaN  (+) Positive       11745.053970
# 4           NaN          NaN          NaN           NaN        -296.549960
# 5           NaN          NaN          NaN           NaN        -255.555703
# 6           NaN          NaN          NaN           NaN        -341.298910
# 7           NaN          NaN          NaN           NaN        -318.044265
# 8           NaN          NaN          NaN           NaN        -170.044976
# 9           NaN          NaN          NaN  (+) Positive       13951.618417
# 10          NaN          NaN          NaN           NaN        -299.419130
# 11          NaN          NaN          NaN           NaN        -219.816186
# 12          NaN          NaN          NaN           NaN        -194.941761
# 13          NaN          NaN          NaN           NaN        7554.641665
# 14          NaN          NaN          NaN           NaN        7818.639573
# 15          NaN          NaN          NaN           NaN        8226.629453
# 16          NaN          NaN          NaN           NaN        5209.031560
# 17          NaN          NaN          NaN           NaN        6502.413635
# 18          NaN          NaN          NaN           NaN        6375.628495
# 19          NaN          NaN          NaN           NaN        6144.277569
# 20          NaN          NaN          NaN           NaN        7088.238705
# 21          NaN          NaN          NaN           NaN        6199.542752
# 22          NaN          NaN          NaN           NaN        7200.890225
# 23          NaN          NaN          NaN           NaN        4989.044555
# 24          NaN          NaN          NaN           NaN        6068.575008
# 25          NaN          NaN          NaN           NaN        6317.944564
# 26          NaN          NaN          NaN           NaN        7240.526975
# 27          NaN          NaN          NaN           NaN        7520.111349
#
#       Negative
# 0   Valid Ctrl
# 1     Negative
# 2     Negative
# 3   Valid Ctrl
# 4     Negative
# 5     Negative
# 6     Negative
# 7     Negative
# 8     Negative
# 9     Positive
# 10    Negative
# 11    Negative
# 12    Negative
# 13    Negative
# 14    Negative
# 15  Valid Ctrl
# 16    Negative
# 17    Negative
# 18  Valid Ctrl
# 19    Negative
# 20    Negative
# 21    Negative
# 22    Negative
# 23    Negative
# 24    Positive
# 25    Negative
# 26    Negative
# 27    Negative

# %%
rawdf = rawdf[rawdf.Fluor !='HEX']
rawdf=rawdf.rename(index=str,columns={'Sample': 'sample_number'})
rawdf = rawdf[pd.notnull(rawdf['sample_number'])]
rawdf=rawdf.astype({"sample_number": int})
rawdf=rawdf.astype({"sample_number": str})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-358a57e54ef4> in <module>()
# ----> 1 rawdf = rawdf[rawdf.Fluor !='HEX']
#       2 rawdf=rawdf.rename(index=str,columns={'Sample': 'sample_number'})
#       3 rawdf = rawdf[pd.notnull(rawdf['sample_number'])]
#       4 rawdf=rawdf.astype({"sample_number": int})
#       5 rawdf=rawdf.astype({"sample_number": str})
#
# c:\users\agundlapalli\appdata\local\programs\python\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Fluor'

# %%
rawdf
# Out:
#    Well Fluor  Target Content  Replicate sample_number  Biological Set Name  \
# 0   A01   FAM     NaN    Unkn        NaN     388636647                  NaN
# 1   A02   FAM     NaN    Unkn        NaN     388637254                  NaN
# 2   B01   FAM     NaN    Unkn        NaN     388636677                  NaN
# 3   B02   FAM     NaN    Unkn        NaN     388637346                  NaN
# 4   C01   FAM     NaN    Unkn        NaN     388636754                  NaN
# 5   C02   FAM     NaN    Unkn        NaN     388637364                  NaN
# 6   D01   FAM     NaN    Unkn        NaN     388636976                  NaN
# 7   D02   FAM     NaN    Unkn        NaN     388640562                  NaN
# 8   E01   FAM     NaN    Unkn        NaN     388637092                  NaN
# 9   E02   FAM     NaN    Unkn        NaN     388640596                  NaN
# 10  F01   FAM     NaN    Unkn        NaN     388637127                  NaN
# 11  G01   FAM     NaN    Unkn        NaN     388637159                  NaN
# 13  H01   FAM     NaN    Unkn        NaN     388637220                  NaN
#
#     Well Note         Cq  Starting Quantity (SQ)    Cq Mean  Cq Std. Dev  \
# 0         NaN        NaN                     NaN   0.000000            0
# 1         NaN        NaN                     NaN   0.000000            0
# 2         NaN        NaN                     NaN   0.000000            0
# 3         NaN        NaN                     NaN   0.000000            0
# 4         NaN        NaN                     NaN   0.000000            0
# 5         NaN        NaN                     NaN   0.000000            0
# 6         NaN        NaN                     NaN   0.000000            0
# 7         NaN        NaN                     NaN   0.000000            0
# 8         NaN        NaN                     NaN   0.000000            0
# 9         NaN  25.771888                     NaN  25.771888            0
# 10        NaN        NaN                     NaN   0.000000            0
# 11        NaN        NaN                     NaN   0.000000            0
# 13        NaN        NaN                     NaN   0.000000            0
#
#     SQ Std. Dev  Melt Temperature  Peak Height  Begin Temperature  \
# 0             0               NaN          NaN                NaN
# 1             0               NaN          NaN                NaN
# 2             0               NaN          NaN                NaN
# 3             0               NaN          NaN                NaN
# 4             0               NaN          NaN                NaN
# 5             0               NaN          NaN                NaN
# 6             0               NaN          NaN                NaN
# 7             0               NaN          NaN                NaN
# 8             0               NaN          NaN                NaN
# 9             0               NaN          NaN                NaN
# 10            0               NaN          NaN                NaN
# 11            0               NaN          NaN                NaN
# 13            0               NaN          NaN                NaN
#
#     End Temperature          Call       End RFU    Result
# 0               NaN           NaN    -31.429438  Negative
# 1               NaN           NaN   -309.770103  Negative
# 2               NaN           NaN    -50.750056  Negative
# 3               NaN           NaN    -45.592750  Negative
# 4               NaN           NaN   -167.223127  Negative
# 5               NaN           NaN   -173.314916  Negative
# 6               NaN           NaN    -92.998778  Negative
# 7               NaN           NaN   -266.115857  Negative
# 8               NaN           NaN   -215.051414  Negative
# 9               NaN  (+) Positive  11590.654082  Positive
# 10              NaN           NaN   -213.296165  Negative
# 11              NaN           NaN   -307.664306  Negative
# 13              NaN           NaN    -72.431937  Negative

# %%
sampleNumbersList=list(rawdf['sample_number'].unique())
databasedf=getDataFromDB(sampleNumbersList)
rawdf=rawdf.astype({"sample_number": int})
dfResult = rawdf.merge(databasedf, how = 'inner', on = ['sample_number'])

# %%
dfResult=dfResult.rename(index=str, 
columns={'sample_number': 'Sample.Sample_Number', 'Result': 'Result.Entry','test_number':'Test.Test_Number'})

# %%
dfResultReplicateMax = dfResult.groupby('Sample.Sample_Number')['replicate_count'].max().reset_index()
dfResultFinal = dfResult.merge(dfResultReplicateMax, how = 'inner', on = ['Sample.Sample_Number','replicate_count'])

# %%
dfResultFinal['Result.Name']='PCR'
dfResultFinal['Result.Entered_By']='IMPORTER'
dfResultFinal['Result.Instrument']='BIO-RAD'
dfResultFinal = dfResultFinal[colsOrder]

# %%
dfResultFinal
# Out:
#     Sample.Sample_Number  Test.Test_Number Result.Name Result.Entry  \
# 0              388636647         649072651         PCR     Negative
# 1              388637254         649084948         PCR     Negative
# 2              388636677         649072656         PCR     Negative
# 3              388637346         649085459         PCR     Negative
# 4              388636754         649072660         PCR     Negative
# 5              388637364         649085463         PCR     Negative
# 6              388636976         649072665         PCR     Negative
# 7              388640562         649091385         PCR     Negative
# 8              388637092         649072669         PCR     Negative
# 9              388640596         649091940         PCR     Positive
# 10             388637127         649084934         PCR     Negative
# 11             388637159         649084938         PCR     Negative
# 12             388637220         649084943         PCR     Negative
#
#    Result.Entered_By Result.Instrument
# 0           IMPORTER           BIO-RAD
# 1           IMPORTER           BIO-RAD
# 2           IMPORTER           BIO-RAD
# 3           IMPORTER           BIO-RAD
# 4           IMPORTER           BIO-RAD
# 5           IMPORTER           BIO-RAD
# 6           IMPORTER           BIO-RAD
# 7           IMPORTER           BIO-RAD
# 8           IMPORTER           BIO-RAD
# 9           IMPORTER           BIO-RAD
# 10          IMPORTER           BIO-RAD
# 11          IMPORTER           BIO-RAD
# 12          IMPORTER           BIO-RAD

# %%
writeFile(dfResultFinal,lab,inst,path,importDest,datapath,fname)
